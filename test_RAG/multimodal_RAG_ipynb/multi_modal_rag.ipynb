# %%
! pip install -U langchain openai chromadb langchain-experimental
# Out:
# Requirement already satisfied: langchain in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (0.3.27)
# Collecting openai
#   Downloading openai-2.7.1-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 8.2 MB/s eta 0:00:01
# Collecting chromadb
#   Downloading chromadb-1.3.4-cp39-abi3-macosx_11_0_arm64.whl (19.2 MB)
#      |████████████████████████████████| 19.2 MB 43.2 MB/s eta 0:00:01
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 35.8 MB/s eta 0:00:01
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain) (2.0.44)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain) (0.4.37)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain) (6.0.3)
# Requirement already satisfied: requests<3,>=2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain) (0.3.79)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from openai) (4.11.0)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: sniffio in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from openai) (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from openai) (0.28.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from openai) (4.15.0)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.12.0-cp39-cp39-macosx_11_0_arm64.whl (312 kB)
#      |████████████████████████████████| 312 kB 72.3 MB/s eta 0:00:01
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 7.4 MB/s eta 0:00:011
# Collecting rich>=10.11.0
#   Downloading rich-14.2.0-py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 51.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.22.5 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (2.0.2)
# Collecting build>=1.0.3
#   Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 61.0 MB/s eta 0:00:01
# Collecting typer>=0.9.0
#   Downloading typer-0.20.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 6.0 MB/s eta 0:00:011
# Requirement already satisfied: tenacity>=8.2.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (9.1.2)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (1.19.2)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.2.0-cp39-cp39-macosx_11_0_arm64.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.0 MB/s eta 0:00:011
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 6.6 MB/s eta 0:00:011
# Collecting posthog<6.0.0,>=2.4.0
#   Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
#      |████████████████████████████████| 105 kB 43.8 MB/s eta 0:00:01
# Requirement already satisfied: orjson>=3.9.12 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (3.11.4)
# Collecting pybase64>=1.4.1
#   Downloading pybase64-1.4.2-cp39-cp39-macosx_11_0_arm64.whl (31 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl (19 kB)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
#      |████████████████████████████████| 495 kB 80.8 MB/s eta 0:00:01
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      |████████████████████████████████| 67 kB 7.6 MB/s eta 0:00:011
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting jsonschema>=4.19.0
#   Downloading jsonschema-4.25.1-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.8 MB/s  eta 0:00:01
# Requirement already satisfied: importlib-resources in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (0.22.1)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 60.0 MB/s eta 0:00:01
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain-experimental) (0.3.31)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=19.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.7.0)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.23.0)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.27.1-cp39-cp39-macosx_11_0_arm64.whl (354 kB)
#      |████████████████████████████████| 354 kB 38.1 MB/s eta 0:00:01
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: six>=1.9.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Collecting urllib3<2.4.0,>=1.24.2
#   Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting requests-oauthlib
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 3.3 MB/s eta 0:00:011
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.6.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.13.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.7.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.22.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.8.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.4.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.26.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: flatbuffers in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: sympy in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: coloredlogs in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: protobuf in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.0)
# Collecting opentelemetry-proto==1.38.0
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 5.8 MB/s  eta 0:00:01
# Collecting opentelemetry-exporter-otlp-proto-common==1.38.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Collecting opentelemetry-semantic-conventions==0.59b0
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 61.4 MB/s eta 0:00:01
# Requirement already satisfied: backoff>=1.10.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: filelock in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: click>=8.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.1.0)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.1.1-cp39-cp39-macosx_11_0_arm64.whl (396 kB)
#      |████████████████████████████████| 396 kB 53.7 MB/s eta 0:00:01
# Collecting websockets>=10.4
#   Downloading websockets-15.0.1-cp39-cp39-macosx_11_0_arm64.whl (173 kB)
#      |████████████████████████████████| 173 kB 73.3 MB/s eta 0:00:01
# Collecting uvloop>=0.15.1
#   Downloading uvloop-0.22.1-cp39-cp39-macosx_10_9_universal2.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 54.4 MB/s eta 0:00:01
# Collecting httptools>=0.6.3
#   Downloading httptools-0.7.1-cp39-cp39-macosx_11_0_arm64.whl (110 kB)
#      |████████████████████████████████| 110 kB 9.8 MB/s eta 0:00:01
# Requirement already satisfied: humanfriendly>=9.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 72.2 MB/s eta 0:00:01
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (PEP 517) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=8ff7a87dfb70a42b83374fde338a5f766e35b93741909c4761a4a4bac7f07395
#   Stored in directory: /Users/jy/Library/Caches/pip/wheels/f7/02/64/d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: urllib3, rpds-py, opentelemetry-api, mdurl, referencing, opentelemetry-semantic-conventions, opentelemetry-proto, oauthlib, markdown-it-py, websockets, websocket-client, watchfiles, uvloop, uvicorn, tomli, shellingham, rich, requests-oauthlib, pyproject-hooks, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-common, jsonschema-specifications, httptools, durationpy, distro, typer, pypika, pybase64, posthog, overrides, opentelemetry-exporter-otlp-proto-grpc, mmh3, kubernetes, jsonschema, jiter, build, bcrypt, openai, langchain-experimental, chromadb
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# Successfully installed bcrypt-5.0.0 build-1.3.0 chromadb-1.3.4 distro-1.9.0 durationpy-0.10 httptools-0.7.1 jiter-0.12.0 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 kubernetes-34.1.0 langchain-experimental-0.3.4 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.2.0 oauthlib-3.3.1 openai-2.7.1 opentelemetry-api-1.38.0 opentelemetry-exporter-otlp-proto-common-1.38.0 opentelemetry-exporter-otlp-proto-grpc-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 overrides-7.7.0 posthog-5.4.0 pybase64-1.4.2 pypika-0.48.9 pyproject-hooks-1.2.0 referencing-0.36.2 requests-oauthlib-2.0.0 rich-14.2.0 rpds-py-0.27.1 shellingham-1.5.4 tomli-2.3.0 typer-0.20.0 urllib3-2.3.0 uvicorn-0.38.0 uvloop-0.22.1 watchfiles-1.1.1 websocket-client-1.9.0 websockets-15.0.1
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/jy/Documents/우테코오픈코스/woo/bin/python3 -m pip install --upgrade pip' command.

# %%
! pip install "unstructured[all-docs]" pillow pydantic lxml pillow matplotlib chromadb tiktoken
# Out:
# Requirement already satisfied: unstructured[all-docs] in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (0.18.3)
# Requirement already satisfied: pillow in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (11.3.0)
# Requirement already satisfied: pydantic in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (2.12.4)
# Requirement already satisfied: lxml in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (6.0.2)
# Requirement already satisfied: matplotlib in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: chromadb in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (1.3.4)
# Collecting tiktoken
#   Downloading tiktoken-0.12.0-cp39-cp39-macosx_11_0_arm64.whl (997 kB)
#      |████████████████████████████████| 997 kB 4.9 MB/s eta 0:00:01
# Requirement already satisfied: rapidfuzz in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (3.13.0)
# Requirement already satisfied: emoji in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (2.15.0)
# Requirement already satisfied: html5lib in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.1)
# Requirement already satisfied: backoff in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (2.2.1)
# Requirement already satisfied: chardet in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (5.2.0)
# Requirement already satisfied: requests in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (4.14.2)
# Requirement already satisfied: psutil in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (7.1.3)
# Requirement already satisfied: typing-extensions in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (4.15.0)
# Requirement already satisfied: python-magic in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (0.4.27)
# Requirement already satisfied: langdetect in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.0.9)
# Requirement already satisfied: python-iso639 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (2025.2.18)
# Requirement already satisfied: nltk in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (3.9.2)
# Requirement already satisfied: tqdm in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (4.67.1)
# Requirement already satisfied: wrapt in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (2.0.1)
# Requirement already satisfied: dataclasses-json in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (0.6.7)
# Requirement already satisfied: filetype in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: numpy in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (2.0.2)
# Requirement already satisfied: python-oxmsg in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (0.0.2)
# Requirement already satisfied: unstructured-client in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (0.42.3)
# Requirement already satisfied: pandas in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (2.3.3)
# Requirement already satisfied: pi-heif in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.1.1)
# Requirement already satisfied: openpyxl in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (3.1.5)
# Requirement already satisfied: python-pptx>=1.0.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.0.2)
# Requirement already satisfied: markdown in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (3.9)
# Requirement already satisfied: unstructured-inference>=1.0.5 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.1.1)
# Requirement already satisfied: pdfminer.six in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (20250506)
# Requirement already satisfied: effdet in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (0.4.1)
# Requirement already satisfied: networkx in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (3.2.1)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (0.3.15)
# Requirement already satisfied: onnx>=1.17.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.19.1)
# Requirement already satisfied: pypandoc in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.15)
# Requirement already satisfied: onnxruntime>=1.19.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.19.2)
# Requirement already satisfied: xlrd in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (2.0.2)
# Requirement already satisfied: pypdf in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (6.1.3)
# Requirement already satisfied: pdf2image in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: python-docx>=1.1.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: pikepdf in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (9.11.0)
# Requirement already satisfied: google-cloud-vision in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured[all-docs]) (3.11.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: cycler>=0.10 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: packaging>=20.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: typer>=0.9.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: httpx>=0.27.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: orjson>=3.9.12 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: overrides>=7.3.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: build>=1.0.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (0.38.0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: tomli>=1.1.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.3.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.7.0)
# Requirement already satisfied: pyproject_hooks in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (4.11.0)
# Requirement already satisfied: idna in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: httpcore==1.* in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: certifi in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2025.10.5)
# Requirement already satisfied: h11>=0.16 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.23.0)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: requests-oauthlib in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: six>=1.9.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.1)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnx>=1.17.0->unstructured[all-docs]) (6.33.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnx>=1.17.0->unstructured[all-docs]) (0.5.3)
# Requirement already satisfied: coloredlogs in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnxruntime>=1.19.0->unstructured[all-docs]) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnxruntime>=1.19.0->unstructured[all-docs]) (25.9.23)
# Requirement already satisfied: sympy in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from onnxruntime>=1.19.0->unstructured[all-docs]) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: distro>=1.5.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from python-pptx>=1.0.1->unstructured[all-docs]) (3.2.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from requests->unstructured[all-docs]) (3.4.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: filelock in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: python-multipart in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-inference>=1.0.5->unstructured[all-docs]) (0.0.20)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-inference>=1.0.5->unstructured[all-docs]) (4.12.0.88)
# Requirement already satisfied: accelerate in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-inference>=1.0.5->unstructured[all-docs]) (1.10.1)
# Requirement already satisfied: torch in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-inference>=1.0.5->unstructured[all-docs]) (2.8.0)
# Requirement already satisfied: scipy in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-inference>=1.0.5->unstructured[all-docs]) (1.13.1)
# Requirement already satisfied: timm in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-inference>=1.0.5->unstructured[all-docs]) (1.0.22)
# Requirement already satisfied: transformers>=4.25.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-inference>=1.0.5->unstructured[all-docs]) (4.57.1)
# Requirement already satisfied: pypdfium2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-inference>=1.0.5->unstructured[all-docs]) (5.0.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[all-docs]) (0.6.2)
# Requirement already satisfied: httptools>=0.6.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: jinja2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from torch->unstructured-inference>=1.0.5->unstructured[all-docs]) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from sympy->onnxruntime>=1.19.0->unstructured[all-docs]) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from beautifulsoup4->unstructured[all-docs]) (2.8)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.19.0->unstructured[all-docs]) (10.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from dataclasses-json->unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from dataclasses-json->unstructured[all-docs]) (3.26.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[all-docs]) (1.1.0)
# Requirement already satisfied: omegaconf>=2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from effdet->unstructured[all-docs]) (2.3.0)
# Requirement already satisfied: torchvision in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from effdet->unstructured[all-docs]) (0.23.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from effdet->unstructured[all-docs]) (2.0.10)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]) (4.9.3)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-cloud-vision->unstructured[all-docs]) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-cloud-vision->unstructured[all-docs]) (1.26.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.76.0)
# Requirement already satisfied: webencodings in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from html5lib->unstructured[all-docs]) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from jinja2->torch->unstructured-inference>=1.0.5->unstructured[all-docs]) (3.0.3)
# Requirement already satisfied: joblib in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from nltk->unstructured[all-docs]) (1.5.2)
# Requirement already satisfied: et-xmlfile in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from openpyxl->unstructured[all-docs]) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pandas->unstructured[all-docs]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pandas->unstructured[all-docs]) (2025.2)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pdfminer.six->unstructured[all-docs]) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.0.0)
# Requirement already satisfied: pycparser in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.23)
# Requirement already satisfied: Deprecated in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from pikepdf->unstructured[all-docs]) (1.3.1)
# Requirement already satisfied: olefile in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from python-oxmsg->unstructured[all-docs]) (0.47)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-client->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/jy/Documents/우테코오픈코스/woo/lib/python3.9/site-packages (from unstructured-client->unstructured[all-docs]) (25.1.0)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.12.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/jy/Documents/우테코오픈코스/woo/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ### PDF 텍스트와 이미지 분할
# Unstructured에서 제공하는 partition_pdf를 사용하여 텍스트와 이미지를 추출
# 이미지 추출: extract_images_in_pdf=True

# %%
#파일 경로 설정
fpath = "../input/"
fname = "cj.pdf"

# %%
import os
from langchain_text_splitters import CharacterTextSplitter
from unstructured.partition.pdf import partition_pdf

# PDF에서 요소 추출


def extract_pdf_elements(path, fname):
    """
    PDF 파일에서 이미지, 테이블, 그리고 텍스트 조각을 추출합니다.
    path: 이미지(.jpg)를 저장할 파일 경로
    fname: 파일 이름
    """
    return partition_pdf(
        filename=os.path.join(path, fname),
        extract_images_in_pdf=True,  # PDF 내 이미지 추출 활성화
        infer_table_structure=True,  # 테이블 구조 추론 활성화
        chunking_strategy="by_title",  # 제목별로 텍스트 조각화
        max_characters=4000,  # 최대 문자 수
        new_after_n_chars=3800,  # 이 문자 수 이후에 새로운 조각 생성
        combine_text_under_n_chars=2000,  # 이 문자 수 이하의 텍스트는 결합
        image_output_dir_path=path,  # 이미지 출력 디렉토리 경로
    )


# 요소를 유형별로 분류


def categorize_elements(raw_pdf_elements):
    """
    PDF에서 추출된 요소를 테이블과 텍스트로 분류합니다.
    raw_pdf_elements: unstructured.documents.elements의 리스트
    """
    tables = []  # 테이블 저장 리스트
    texts = []  # 텍스트 저장 리스트
    for element in raw_pdf_elements:
        if "unstructured.documents.elements.Table" in str(type(element)):
            tables.append(str(element))  # 테이블 요소 추가
        elif "unstructured.documents.elements.CompositeElement" in str(type(element)):
            texts.append(str(element))  # 텍스트 요소 추가
    return texts, tables


# 요소 추출
raw_pdf_elements = extract_pdf_elements(fpath, fname)

# 텍스트, 테이블 추출
texts, tables = categorize_elements(raw_pdf_elements)

# 선택사항: 텍스트에 대해 특정 토큰 크기 적용
text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=4000, chunk_overlap=0  # 텍스트를 4000 토큰 크기로 분할, 중복 없음
)
joined_texts = " ".join(texts)  # 텍스트 결합
texts_4k_token = text_splitter.split_text(joined_texts)  # 분할 실행
# Out:
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Created a chunk of size 4129, which is longer than the specified 4000

# %%
len(texts_4k_token) # 여기서 나온 숫자만큼의 청크로 요약본을 만든다
# Out:
# 6

# %% [markdown]
# ### 멀티-벡터 검색기
# multi-vector-retriever를 사용하여 이미지(그리고/또는 텍스트, 테이블) 요약을 색인화하지만, 원본 이미지(원본 텍스트나 테이블과 함께)를 검색
#
# 텍스트 및 테이블 요약
# 테이블과 선택적으로 텍스트 요약을 생성하기 위해 GPT-4-turbo를 사용할 것입니다.
#
# 큰 청크 크기를 사용하는 경우(예를 들어, 위에서 설정한 것처럼 4k 토큰 청크를 사용) 텍스트 요약이 권장됩니다.
#
# 요약은 원본 테이블 및/또는 원본 텍스트 청크를 검색하는 데 사용됩니다.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# 텍스트 요소의 요약 생성


def generate_text_summaries(texts, tables, summarize_texts=False):
    """
    텍스트 요소 요약
    texts: 문자열 리스트
    tables: 문자열 리스트
    summarize_texts: 텍스트 요약 여부를 결정. True/False
    """
 
    # 프롬프트 설정
    prompt_text = """You are an assistant tasked with summarizing tables and text for retrieval. \
    These summaries will be embedded and used to retrieve the raw text or table elements. \
    Give a concise summary of the table or text that is well optimized for retrieval. Table or text: {element} """
    prompt = ChatPromptTemplate.from_template(prompt_text)

    # 텍스트 요약 체인
    model = ChatOpenAI(temperature=0, model="gpt-4o-mini")
    summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()

    # 요약을 위한 빈 리스트 초기화
    text_summaries = []
    table_summaries = []

    # 제공된 텍스트에 대해 요약이 요청되었을 경우 적용
    if texts and summarize_texts:
        text_summaries = summarize_chain.batch(texts, {"max_concurrency": 5})
    elif texts:
        text_summaries = texts

    # 제공된 테이블에 적용
    if tables:
        table_summaries = summarize_chain.batch(tables, {"max_concurrency": 5})

    return text_summaries, table_summaries


# 텍스트, 테이블 요약 가져오기
text_summaries, table_summaries = generate_text_summaries(
    texts_4k_token, tables, summarize_texts=True
)

# %% [markdown]
# ### 이미지 요약
# GPT-4o를 사용하여 이미지 요약
# base64로 인코딩된 이미지를 전달

# %%
import base64
import os

from langchain_core.messages import HumanMessage


def encode_image(image_path):
    # 이미지 파일을 base64 문자열로 인코딩합니다.
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


def image_summarize(img_base64, prompt):
    # 이미지 요약을 생성합니다.
    chat = ChatOpenAI(model="gpt-4o-mini", max_tokens=2048)

    msg = chat.invoke(
        [
            HumanMessage(
                content=[
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/jpeg;base64,{img_base64}"},
                    },
                ]
            )
        ]
    )
    return msg.content


def generate_img_summaries(path):
    """
    이미지에 대한 요약과 base64 인코딩된 문자열을 생성합니다.
    path: Unstructured에 의해 추출된 .jpg 파일 목록의 경로
    """

    # base64로 인코딩된 이미지를 저장할 리스트
    img_base64_list = []

    # 이미지 요약을 저장할 리스트
    image_summaries = []

    # 요약을 위한 프롬프트
    prompt = """You are an assistant tasked with summarizing images for retrieval. \
    These summaries will be embedded and used to retrieve the raw image. \
    Give a concise summary of the image that is well optimized for retrieval."""

    # 이미지에 적용
    for img_file in sorted(os.listdir(path)):
        if img_file.endswith(".jpg"):
            img_path = os.path.join(path, img_file)
            base64_image = encode_image(img_path)
            img_base64_list.append(base64_image)
            image_summaries.append(image_summarize(base64_image, prompt))

    return img_base64_list, image_summaries


# 이미지 요약 실행
figure_path = "../multimodal_RAG/figures"
img_base64_list, image_summaries = generate_img_summaries(figure_path)

# %%
len(image_summaries)
# Out:
# 19

# %%
import os
print(os.listdir(fpath))
# Out:
# ['테스트.pdf', 'cj.pdf', '책.pdf', 'sin.pdf']

# %% [markdown]
# ### 벡터 저장소에 추가하기
# 원본 문서와 문서 요약을 Multi Vector Retriever에 추가하는 방법:
# - 원본 텍스트, 테이블, 이미지를 docstore에 저장
# - 텍스트, 테이블 요약, 이미지 요약을 vectorstore에 저장

# %%
import uuid

from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.storage import InMemoryStore
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings


def create_multi_vector_retriever(
    vectorstore, text_summaries, texts, table_summaries, tables, image_summaries, images
):
    """
    요약을 색인화하지만 원본 이미지나 텍스트를 반환하는 검색기를 생성합니다.
    """

    # 저장 계층 초기화
    store = InMemoryStore()
    id_key = "doc_id"

    # 멀티 벡터 검색기 생성
    retriever = MultiVectorRetriever(
        vectorstore=vectorstore,
        docstore=store,
        id_key=id_key,
    )

    # 문서를 벡터 저장소와 문서 저장소에 추가하는 헬퍼 함수
    def add_documents(retriever, doc_summaries, doc_contents):
        doc_ids = [
            str(uuid.uuid4()) for _ in doc_contents
        ]  # 문서 내용마다 고유 ID 생성
        summary_docs = [
            Document(page_content=s, metadata={id_key: doc_ids[i]})
            for i, s in enumerate(doc_summaries)
        ]
        retriever.vectorstore.add_documents(
            summary_docs
        )  # 요약 문서를 벡터 저장소에 추가
        retriever.docstore.mset(
            list(zip(doc_ids, doc_contents))
        )  # 문서 내용을 문서 저장소에 추가

    # 텍스트, 테이블, 이미지 추가
    if text_summaries:
        add_documents(retriever, text_summaries, texts)

    if table_summaries:
        add_documents(retriever, table_summaries, tables)

    if image_summaries:
        add_documents(retriever, image_summaries, images)

    return retriever

# %%
# 요약을 색인화하기 위해 사용할 벡터 저장소
vectorstore = Chroma(
    collection_name="sample-rag-multi-modal", embedding_function=OpenAIEmbeddings()
)

# 검색기 생성
retriever_multi_vector_img = create_multi_vector_retriever(
    vectorstore,
    text_summaries,
    texts,
    table_summaries,
    tables,
    image_summaries,
    img_base64_list,
)

# %% [markdown]
# ### RAG
# 검색기 구축
# 검색된 문서를 GPT-4o 프롬프트 템플릿의 올바른 부분에 할당해야 합니다.
#
# 다음은 Base64 인코딩된 이미지와 텍스트를 처리하고, 이를 활용하여 다중 모달 질의응답(질문-응답) 체인을 구성하는 방법을 설명합니다.
#
# Base64 인코딩된 문자열이 이미지인지 확인합니다. 지원하는 이미지 포맷은 JPG, PNG, GIF, WEBP입니다.
# Base64 인코딩된 이미지를 주어진 크기로 리사이즈합니다.
# 문서 집합에서 Base64 인코딩된 이미지와 텍스트를 분리합니다.
# 분리된 이미지와 텍스트를 사용하여 다중 모달 질의응답 체인의 입력으로 사용될 메시지를 구성합니다. 이 과정에서 이미지 URL과 텍스트 정보를 포함하는 메시지를 생성합니다.
# 다중 모달 질의응답 체인을 구성합니다. 이 체인은 입력된 이미지와 텍스트 정보를 바탕으로 질문에 대한 응답을 생성하는 과정을 포함합니다. 사용된 모델은 ChatOpenAI이며, gpt-4o 모델을 사용합니다.
# 이 과정은 이미지와 텍스트 데이터를 모두 활용하여 질문에 대한 응답을 생성하는 다중 모달 질의응답 시스템을 구현하는 방법을 제시합니다. 여기서는 이미지 데이터를 처리하기 위한 Base64 인코딩 및 디코딩, 이미지 리사이징, 그리고 이를 텍스트 정보와 함께 처리하여 질문에 대한 응답을 생성하는 과정이 포함됩니다.

# %%
import io
import re

from IPython.display import HTML, display
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from PIL import Image


def plt_img_base64(img_base64):
    """base64 인코딩된 문자열을 이미지로 표시"""
    # base64 문자열을 소스로 사용하는 HTML img 태그 생성
    image_html = f'<img src="data:image/jpeg;base64,{img_base64}" />'
    # HTML을 렌더링하여 이미지 표시
    display(HTML(image_html))


def looks_like_base64(sb):
    """문자열이 base64로 보이는지 확인"""
    return re.match("^[A-Za-z0-9+/]+[=]{0,2}$", sb) is not None


def is_image_data(b64data):
    """
    base64 데이터가 이미지인지 시작 부분을 보고 확인
    """
    image_signatures = {
        b"\xff\xd8\xff": "jpg",
        b"\x89\x50\x4e\x47\x0d\x0a\x1a\x0a": "png",
        b"\x47\x49\x46\x38": "gif",
        b"\x52\x49\x46\x46": "webp",
    }
    try:
        header = base64.b64decode(b64data)[:8]  # 처음 8바이트를 디코드하여 가져옴
        for sig, format in image_signatures.items():
            if header.startswith(sig):
                return True
        return False
    except Exception:
        return False


def resize_base64_image(base64_string, size=(128, 128)):
    """
    Base64 문자열로 인코딩된 이미지의 크기 조정
    """
    # Base64 문자열 디코드
    img_data = base64.b64decode(base64_string)
    img = Image.open(io.BytesIO(img_data))

    # 이미지 크기 조정
    resized_img = img.resize(size, Image.LANCZOS)

    # 조정된 이미지를 바이트 버퍼에 저장
    buffered = io.BytesIO()
    resized_img.save(buffered, format=img.format)

    # 조정된 이미지를 Base64로 인코딩
    return base64.b64encode(buffered.getvalue()).decode("utf-8")


def split_image_text_types(docs):
    """
    base64로 인코딩된 이미지와 텍스트 분리
    """
    b64_images = []
    texts = []
    for doc in docs:
        # 문서가 Document 타입인 경우 page_content 추출
        if isinstance(doc, Document):
            doc = doc.page_content
        if looks_like_base64(doc) and is_image_data(doc):
            doc = resize_base64_image(doc, size=(1300, 600))
            b64_images.append(doc)
        else:
            texts.append(doc)
    return {"images": b64_images, "texts": texts}


def img_prompt_func(data_dict):
    """
    컨텍스트를 단일 문자열로 결합
    """
    formatted_texts = "\n".join(data_dict["context"]["texts"])
    messages = []

    # 이미지가 있으면 메시지에 추가
    if data_dict["context"]["images"]:
        for image in data_dict["context"]["images"]:
            image_message = {
                "type": "image_url",
                "image_url": {"url": f"data:image/jpeg;base64,{image}"},
            }
            messages.append(image_message)

    # 분석을 위한 텍스트 추가
    text_message = {
        "type": "text",
        "text": (
            "You are financial analyst tasking with providing investment advice.\n"
            "You will be given a mixed of text, tables, and image(s) usually of charts or graphs.\n"
            "Use this information to provide investment advice related to the user question. Answer in Korean. Do NOT translate company names.\n"
            f"User-provided question: {data_dict['question']}\n\n"
            "Text and / or tables:\n"
            f"{formatted_texts}"
        ),
    }
    messages.append(text_message)
    return [HumanMessage(content=messages)]


def multi_modal_rag_chain(retriever):
    """
    멀티모달 RAG 체인
    """

    # 멀티모달 LLM
    model = ChatOpenAI(temperature=0, model="gpt-4o-mini", max_tokens=2048)

    # RAG 파이프라인
    chain = (
        {
            "context": retriever | RunnableLambda(split_image_text_types),
            "question": RunnablePassthrough(),
        }
        | RunnableLambda(img_prompt_func)
        | model
        | StrOutputParser()
    )

    return chain


# RAG 체인 생성
chain_multimodal_rag = multi_modal_rag_chain(retriever_multi_vector_img)

# %% [markdown]
# ### 검사
# 우리가 질문에 관련된 이미지를 검색할 때, 관련성 있는 이미지들을 되돌려 받습니다.

# %%
# 검색 결과 확인
query = " are the EV / NTM and NTM rev growth for MongoDB, Cloudflare, and Datadog?"
docs = retriever_multi_vector_img.invoke(query, limit=1)

# 문서의 개수 확인
len(docs)
# Out:
# 2

# %%
# 관련 이미지를 반환합니다.
plt_img_base64(docs[0])
# Out:
# <img src="...$39.2M Squarespace $257.1M Jamf $142.6M Kaltura $43.5M CS Disco $34.9M 2U $229.7M Olo $57.8M Alteryx $232.0M RingCentral $558.2M Klaviyo $175.8M Datadog $547.5M Amplitude $70.6M Hubspot $557.6M BigCommerce $78.0M Twilio $1033.6M Wix.com $393.8M Reported Revenue Consensus $38.0M $251.8M $140.0M $43.1M $34.1M $223.4M $56.3M $210.3M $554.0M $167.4M $523.2M $70.0M $533.0M $78.0M $986.9M $389.7M 3.2% 2.1% 1.9% 1.0% 2.3% 2.8% 27% 10.3% 0.8% 5.0% 46% 0.9% 46% 0.1% 4T% 1.0% Guidance $37.3M $262.5M $148.5M $41.6M $35.0M NA $58.8M $337.0M $570.0M $196.0M $566.0M $71.6M $557.0M $81.8M $1035.0M $402.5M Next Quarter Rev Consensus $35.4M $256.0M $149.1M $42.2M $38.8M $300.0M $56.9M $337.8M $570.0M $195.1M $541.0M $70.3M $555.8M $82.0M $1029.0M $399.2M 5.4% 2.5% (0.4%) (1.4%) (9.8%) NA 3.3% (0.2%) 0.0% 0.5% 4.6% 1.8% 0.2% (0.2%) 0.6% 0.8%
#
# Top 10 EV / NTM Revenue Multiples
#
# https://cloudedjudgement.substack.com/p/clouded-judgement-111023
#
# 5/21
#
# 11/14/23, 8:35 PM
#
# Clouded Judgement 11.10.23 - by Jamin Ball
#
# EV/NTM EV/2024 EV/NTM NTMRev Gross Operating FCF % in Top 10 Company Rev Rev FCF Growth Margin Margin Margin Multiple LTM 1 Snowflake 15.5x 13.4x 55x 27% 66% (41%) 25% 100% 2 MongoDB 14.6x 12.9x 133x 17% 74% (18%) 3% 67% 3 Palantir 14.5x 13.9x 58x 19% 80% 2% 22% 47% 4 Cloudflare 13.4x 12.6x 153x 28% 76% (16%) 8% 100% 5 Datadog 13.1x 12.4x 52x 19% 80% (5%) 25% 99% 6 CrowdStrike 12.5x 11.1x 37x 31% 74% (6%) 30% 31% 7 Adobe 12.3x 11.9x 30x 12% 88% 34% 40% 26% 8 ServiceNow 12.2x 11.6x 38x 21% 79% 8% 28% 70% 9 Samsara 11.8x 10.5x 393x 31% 72% (34%) (3%) 72% 10 Zscaler 11.8x 10.5x 48x 27% 78% (14%) 21% 36% Overall Median = 50x. 48x 33.7 18% = 75% = (16%) 8% Clouded Judgement @jaminball ALTIMETER
#
# Top 10 Weekly Share Price Movement
#
# https://cloudedjudgement.substack.com/p/clouded-judgement-111023
#
# 6/21
#
# 11/14/23, 8:35 PM
#
# Clouded Judgement 11.10.23 - by Jamin Ball
#
# Company Datadog Alteryx Digital Ocean Couchbase MongoDB Sprout Social Qualys Cloudflare Snowflake 10 Dynatrace OoOOnN Da WN = 7 Day Share Price A 26% 19% 15% 13% 11% 11% 10% 10% 10% 8% Clouded Judgement 30 Day Share Price A 9% (2%) 1% (5%) 2% (7%) 3% (5%) (4%) 1% @jaminbal YTD Share Price A 36% (29%) (4%) 22% 86% (16%) 50% 38% 9% 29% Current Market Cap ($MM) $32,931 $2,597 $2,108 $759 $26,063 $2,642 $6,179 $20,878 $51,549 $14,528 1 ALTIMETER
#
# Update on Multiples
#
# SaaS businesses are generally valued on a multiple of their revenue - in most cases the projected revenue for the next 12 months. Revenue multiples are a shorthand valuation framework. Given most soware companies are not protable, or not generating meaningful FCF, it’s the only metric to compare the entire industry against. Even a DCF is riddled with long term assumptions. The promise of SaaS is that growth in the early years leads to prots in the mature years. Multiples shown below are calculated by taking the Enterprise Value (market cap + debt - cash) / NTM revenue.
#
# Overall Stats:
#
# https://cloudedjudgement.substack.com/p/clouded-judgement-111023
#
# 7/21
#
# 11/14/23, 8:35 PM
#
# Clouded Judgement 11.10.23 - by Jamin Ball
#
# Overall Median: 5.0x
#
# Top 5 Median: 14.5x
#
# 10Y: 4.6%
#
# EV / NTM Revenue Multiples 25.0x 6.0% 20.0x 5.0% . 4.6% 4.0% 15.0x 3.0% 10.0x 7.8K 7.0% 5.0x 5.0x 1.0% 0.0x 0.0% Jan-15 Aug-15 Mar-16 Oct-16 May-17 Dec-17 Jul-18 Feb-19 Sep-19 Apr-20 Nov-20 Jun-21 Jan-22 Aug-22 Mar-23 Oct-23 Median == LT Pre Covid Average —— 10 Year Treasury Clouded Judgement @jaminball ALTIMETER
#
# https://cloudedjudgement.substack.com/p/clouded-judgement-111023
#
# 8/21
#
# 11/14/23, 8:35 PM
#
# Clouded Judgement 11.10.23 - by Jamin Ball
#
# EV / NTM Revenue Multiples 90.0x 80.0x 70.0x 60.0x 50.0x 40.0x 30.0x 20.0x 14.5x 10.0x 5.0x 0.0x Jan-15 Aug-15 Mar-16 Oct-16 May-17 Dec-17 Jul-18 Feb-19 Sep-19 Apr-20 Nov-20 Jun-21 Jan-22 Aug-22 Mar-23 Oct-23 —== Median —=—=Top 5 Median Clouded Judgement @jaminball ALTIMETER" />

# %%
# RAG 체인 실행
print(chain_multimodal_rag.invoke(query))
# Out:
# MongoDB, Cloudflare, 그리고 Datadog의 EV/NTM 및 NTM 매출 성장률은 다음과 같습니다:
#
# 1. **MongoDB**
#    - EV/NTM: 14.6x
#    - NTM 매출 성장률: 17%
#
# 2. **Cloudflare**
#    - EV/NTM: 13.4x
#    - NTM 매출 성장률: 28%
#
# 3. **Datadog**
#    - EV/NTM: 13.1x
#    - NTM 매출 성장률: 19%
#
# 이 정보를 바탕으로, Cloudflare는 가장 높은 매출 성장률을 보이고 있으며, MongoDB는 상대적으로 높은 EV/NTM 배수를 가지고 있습니다. 투자 결정을 내릴 때 이러한 지표들을 고려하는 것이 중요합니다. Cloudflare의 성장 잠재력이 매력적일 수 있으며, MongoDB는 높은 평가를 받고 있지만 성장률이 다소 낮습니다. Datadog은 두 회사의 중간 정도의 성과를 보이고 있습니다.
